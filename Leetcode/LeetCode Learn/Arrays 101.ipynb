# %% [markdown]
# ![image.png](attachment:9d246084-2476-4441-8548-e35993d78eda.png)

# %% [markdown]
# ![image.png](attachment:6037ac06-34c7-4714-8100-793aa4005bbc.png)

# %% [markdown]
# ![image.png](attachment:46f48a83-749c-4509-b934-828d812ba992.png)
